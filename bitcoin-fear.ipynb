# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import numpy as np

# %%
df=pd.read_excel('preco.xlsx')
print(df)
# Out:
#            DATA  FEAR INDEX    PRICE FEAR SITUATION
# 0    2022-01-06          15  43156.6   Extreme Fear
# 1    2022-01-05          24  43425.9   Extreme Fear
# 2    2022-01-04          23  45837.3   Extreme Fear
# 3    2022-01-03          29  46430.2           Fear
# 4    2022-01-02          29  47311.8           Fear
# ...         ...         ...      ...            ...
# 1428 2018-02-05          11   6938.5   Extreme Fear
# 1429 2018-02-04          24   8222.2   Extreme Fear
# 1430 2018-02-03          40   9241.1           Fear
# 1431 2018-02-02          15   8893.2   Extreme Fear
# 1432 2018-02-01          30   9181.1           Fear
#
# [1433 rows x 4 columns]

# %%
x=df['DATA']
y1=df['PRICE']
y2=df['FEAR INDEX']

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(
    go.Scatter(x=x,y=y1,name='PREÇO'),
    secondary_y=False,
)

fig.add_trace(
    go.Scatter(x=x,y=y2,name='ÍNDICE DE MEDO'),
    secondary_y=True,
)

fig.update_layout(
    title_text="Preço X Medo (BTC/USD)"
)

fig.update_xaxes(title_text="DATA")

fig.update_yaxes(title_text="PREÇO<b>BITCOIN</b>\n (BI USD)", secondary_y=False)
fig.update_yaxes(title_text="ÍNDICE DE MEDO", secondary_y=True)

# %%
fear=px.scatter(x=x, y=y1, color=y2)
fear.show()

# %%
import numpy as np
import scipy.optimize as solver
import matplotlib.pyplot as fig

list=['DATA','PRICE','FEAR INDEX']

# %%
sigma=np.cov(y1,y2)*1825

print(' ')
print(' ')
print('MATRIZ DE COVARIÂNCIA DA CARTEIRA')
print(sigma)
# Out:
#
#
# MATRIZ DE COVARIÂNCIA DA CARTEIRA
# [[5.90461234e+11 2.66240224e+08]
#  [2.66240224e+08 9.41332643e+05]]
